# %%
import logging
import os

import pandas as pd
import psycopg2
from startupradar.transformers.core import DomainTextTransformer, WhoisTransformer
from startupradar.transformers.util.api import StartupRadarAPI
import numpy as np

from utils import *

# %%
rating_threshold = 5
keeptop = 100

# %%
df = pd.read_parquet(".data/full.parquet")

# Check for missing values in each column
missing_values = df.isnull().sum()

for (col, val) in zip(missing_values.keys(), missing_values.values):
    if val > 0:
        print(f"Column {col} is missing {val} entries.")

# To find words that are correlated with highly-rated startups, 
# find most occuring words for highly-rated startups and discard 
# those words that also occur frequently for other startups.
df_filtered_good = df.loc[df['Rating'] >= rating_threshold]
words_good = []
for text in df_filtered_good.text:
    words_good += split_text(text)
word_counts_good = get_word_counts(words_good, keeptop=keeptop)

df_filtered_bad = df.loc[df['Rating'] < rating_threshold]
words_bad = []
for text in df_filtered_bad.text:
    words_bad += split_text(text)
word_counts_bad = get_word_counts(words_bad, keeptop=keeptop)

for word_good in word_counts_good.keys():
    if word_good not in word_counts_bad.keys():
        print(f"{word_good}")
# Out:
# Column created is missing 166 entries.
# Column changed is missing 180 entries.
# Column expires is missing 166 entries.
# Column days_since_created is missing 166 entries.
# Column days_since_changed is missing 180 entries.
# Column e0 is missing 95 entries.
# Column e1 is missing 95 entries.
# Column e2 is missing 95 entries.
# Column e3 is missing 95 entries.
# Column e4 is missing 95 entries.
# Column e5 is missing 95 entries.
# Column e6 is missing 95 entries.
# Column e7 is missing 95 entries.
# Column e8 is missing 95 entries.
# Column e9 is missing 95 entries.
# Column e10 is missing 95 entries.
# Column e11 is missing 95 entries.
# Column e12 is missing 95 entries.
# Column e13 is missing 95 entries.
# Column e14 is missing 95 entries.
# Column e15 is missing 95 entries.
# Column e16 is missing 95 entries.
# Column e17 is missing 95 entries.
# Column e18 is missing 95 entries.
# Column e19 is missing 95 entries.
# Column e20 is missing 95 entries.
# Column e21 is missing 95 entries.
# Column e22 is missing 95 entries.
# Column e23 is missing 95 entries.
# Column e24 is missing 95 entries.
# Column e25 is missing 95 entries.
# Column e26 is missing 95 entries.
# Column e27 is missing 95 entries.
# Column e28 is missing 95 entries.
# Column e29 is missing 95 entries.
# Column e30 is missing 95 entries.
# Column e31 is missing 95 entries.
# Column e32 is missing 95 entries.
# Column e33 is missing 95 entries.
# Column e34 is missing 95 entries.
# Column e35 is missing 95 entries.
# Column e36 is missing 95 entries.
# Column e37 is missing 95 entries.
# Column e38 is missing 95 entries.
# Column e39 is missing 95 entries.
# Column e40 is missing 95 entries.
# Column e41 is missing 95 entries.
# Column e42 is missing 95 entries.
# Column e43 is missing 95 entries.
# Column e44 is missing 95 entries.
# Column e45 is missing 95 entries.
# Column e46 is missing 95 entries.
# Column e47 is missing 95 entries.
# Column e48 is missing 95 entries.
# Column e49 is missing 95 entries.
# Column e50 is missing 95 entries.
# Column e51 is missing 95 entries.
# Column e52 is missing 95 entries.
# Column e53 is missing 95 entries.
# Column e54 is missing 95 entries.
# Column e55 is missing 95 entries.
# Column e56 is missing 95 entries.
# Column e57 is missing 95 entries.
# Column e58 is missing 95 entries.
# Column e59 is missing 95 entries.
# Column e60 is missing 95 entries.
# Column e61 is missing 95 entries.
# Column e62 is missing 95 entries.
# Column e63 is missing 95 entries.
# Column e64 is missing 95 entries.
# Column e65 is missing 95 entries.
# Column e66 is missing 95 entries.
# Column e67 is missing 95 entries.
# Column e68 is missing 95 entries.
# Column e69 is missing 95 entries.
# Column e70 is missing 95 entries.
# Column e71 is missing 95 entries.
# Column e72 is missing 95 entries.
# Column e73 is missing 95 entries.
# Column e74 is missing 95 entries.
# Column e75 is missing 95 entries.
# Column e76 is missing 95 entries.
# Column e77 is missing 95 entries.
# Column e78 is missing 95 entries.
# Column e79 is missing 95 entries.
# Column e80 is missing 95 entries.
# Column e81 is missing 95 entries.
# Column e82 is missing 95 entries.
# Column e83 is missing 95 entries.
# Column e84 is missing 95 entries.
# Column e85 is missing 95 entries.
# Column e86 is missing 95 entries.
# Column e87 is missing 95 entries.
# Column e88 is missing 95 entries.
# Column e89 is missing 95 entries.
# Column e90 is missing 95 entries.
# Column e91 is missing 95 entries.
# Column e92 is missing 95 entries.
# Column e93 is missing 95 entries.
# Column e94 is missing 95 entries.
# Column e95 is missing 95 entries.
# Column e96 is missing 95 entries.
# Column e97 is missing 95 entries.
# Column e98 is missing 95 entries.
# Column e99 is missing 95 entries.
# Column e100 is missing 95 entries.
# Column e101 is missing 95 entries.
# Column e102 is missing 95 entries.
# Column e103 is missing 95 entries.
# Column e104 is missing 95 entries.
# Column e105 is missing 95 entries.
# Column e106 is missing 95 entries.
# Column e107 is missing 95 entries.
# Column e108 is missing 95 entries.
# Column e109 is missing 95 entries.
# Column e110 is missing 95 entries.
# Column e111 is missing 95 entries.
# Column e112 is missing 95 entries.
# Column e113 is missing 95 entries.
# Column e114 is missing 95 entries.
# Column e115 is missing 95 entries.
# Column e116 is missing 95 entries.
# Column e117 is missing 95 entries.
# Column e118 is missing 95 entries.
# Column e119 is missing 95 entries.
# Column e120 is missing 95 entries.
# Column e121 is missing 95 entries.
# Column e122 is missing 95 entries.
# Column e123 is missing 95 entries.
# Column e124 is missing 95 entries.
# Column e125 is missing 95 entries.
# Column e126 is missing 95 entries.
# Column e127 is missing 95 entries.
# Column e128 is missing 95 entries.
# Column e129 is missing 95 entries.
# Column e130 is missing 95 entries.
# Column e131 is missing 95 entries.
# Column e132 is missing 95 entries.
# Column e133 is missing 95 entries.
# Column e134 is missing 95 entries.
# Column e135 is missing 95 entries.
# Column e136 is missing 95 entries.
# Column e137 is missing 95 entries.
# Column e138 is missing 95 entries.
# Column e139 is missing 95 entries.
# Column e140 is missing 95 entries.
# Column e141 is missing 95 entries.
# Column e142 is missing 95 entries.
# Column e143 is missing 95 entries.
# Column e144 is missing 95 entries.
# Column e145 is missing 95 entries.
# Column e146 is missing 95 entries.
# Column e147 is missing 95 entries.
# Column e148 is missing 95 entries.
# Column e149 is missing 95 entries.
# Column e150 is missing 95 entries.
# Column e151 is missing 95 entries.
# Column e152 is missing 95 entries.
# Column e153 is missing 95 entries.
# Column e154 is missing 95 entries.
# Column e155 is missing 95 entries.
# Column e156 is missing 95 entries.
# Column e157 is missing 95 entries.
# Column e158 is missing 95 entries.
# Column e159 is missing 95 entries.
# Column e160 is missing 95 entries.
# Column e161 is missing 95 entries.
# Column e162 is missing 95 entries.
# Column e163 is missing 95 entries.
# Column e164 is missing 95 entries.
# Column e165 is missing 95 entries.
# Column e166 is missing 95 entries.
# Column e167 is missing 95 entries.
# Column e168 is missing 95 entries.
# Column e169 is missing 95 entries.
# Column e170 is missing 95 entries.
# Column e171 is missing 95 entries.
# Column e172 is missing 95 entries.
# Column e173 is missing 95 entries.
# Column e174 is missing 95 entries.
# Column e175 is missing 95 entries.
# Column e176 is missing 95 entries.
# Column e177 is missing 95 entries.
# Column e178 is missing 95 entries.
# Column e179 is missing 95 entries.
# Column e180 is missing 95 entries.
# Column e181 is missing 95 entries.
# Column e182 is missing 95 entries.
# Column e183 is missing 95 entries.
# Column e184 is missing 95 entries.
# Column e185 is missing 95 entries.
# Column e186 is missing 95 entries.
# Column e187 is missing 95 entries.
# Column e188 is missing 95 entries.
# Column e189 is missing 95 entries.
# Column e190 is missing 95 entries.
# Column e191 is missing 95 entries.
# Column e192 is missing 95 entries.
# Column e193 is missing 95 entries.
# Column e194 is missing 95 entries.
# Column e195 is missing 95 entries.
# Column e196 is missing 95 entries.
# Column e197 is missing 95 entries.
# Column e198 is missing 95 entries.
# Column e199 is missing 95 entries.
# Column e200 is missing 95 entries.
# Column e201 is missing 95 entries.
# Column e202 is missing 95 entries.
# Column e203 is missing 95 entries.
# Column e204 is missing 95 entries.
# Column e205 is missing 95 entries.
# Column e206 is missing 95 entries.
# Column e207 is missing 95 entries.
# Column e208 is missing 95 entries.
# Column e209 is missing 95 entries.
# Column e210 is missing 95 entries.
# Column e211 is missing 95 entries.
# Column e212 is missing 95 entries.
# Column e213 is missing 95 entries.
# Column e214 is missing 95 entries.
# Column e215 is missing 95 entries.
# Column e216 is missing 95 entries.
# Column e217 is missing 95 entries.
# Column e218 is missing 95 entries.
# Column e219 is missing 95 entries.
# Column e220 is missing 95 entries.
# Column e221 is missing 95 entries.
# Column e222 is missing 95 entries.
# Column e223 is missing 95 entries.
# Column e224 is missing 95 entries.
# Column e225 is missing 95 entries.
# Column e226 is missing 95 entries.
# Column e227 is missing 95 entries.
# Column e228 is missing 95 entries.
# Column e229 is missing 95 entries.
# Column e230 is missing 95 entries.
# Column e231 is missing 95 entries.
# Column e232 is missing 95 entries.
# Column e233 is missing 95 entries.
# Column e234 is missing 95 entries.
# Column e235 is missing 95 entries.
# Column e236 is missing 95 entries.
# Column e237 is missing 95 entries.
# Column e238 is missing 95 entries.
# Column e239 is missing 95 entries.
# Column e240 is missing 95 entries.
# Column e241 is missing 95 entries.
# Column e242 is missing 95 entries.
# Column e243 is missing 95 entries.
# Column e244 is missing 95 entries.
# Column e245 is missing 95 entries.
# Column e246 is missing 95 entries.
# Column e247 is missing 95 entries.
# Column e248 is missing 95 entries.
# Column e249 is missing 95 entries.
# Column e250 is missing 95 entries.
# Column e251 is missing 95 entries.
# Column e252 is missing 95 entries.
# Column e253 is missing 95 entries.
# Column e254 is missing 95 entries.
# Column e255 is missing 95 entries.
# Column e256 is missing 95 entries.
# Column e257 is missing 95 entries.
# Column e258 is missing 95 entries.
# Column e259 is missing 95 entries.
# Column e260 is missing 95 entries.
# Column e261 is missing 95 entries.
# Column e262 is missing 95 entries.
# Column e263 is missing 95 entries.
# Column e264 is missing 95 entries.
# Column e265 is missing 95 entries.
# Column e266 is missing 95 entries.
# Column e267 is missing 95 entries.
# Column e268 is missing 95 entries.
# Column e269 is missing 95 entries.
# Column e270 is missing 95 entries.
# Column e271 is missing 95 entries.
# Column e272 is missing 95 entries.
# Column e273 is missing 95 entries.
# Column e274 is missing 95 entries.
# Column e275 is missing 95 entries.
# Column e276 is missing 95 entries.
# Column e277 is missing 95 entries.
# Column e278 is missing 95 entries.
# Column e279 is missing 95 entries.
# Column e280 is missing 95 entries.
# Column e281 is missing 95 entries.
# Column e282 is missing 95 entries.
# Column e283 is missing 95 entries.
# Column e284 is missing 95 entries.
# Column e285 is missing 95 entries.
# Column e286 is missing 95 entries.
# Column e287 is missing 95 entries.
# Column e288 is missing 95 entries.
# Column e289 is missing 95 entries.
# Column e290 is missing 95 entries.
# Column e291 is missing 95 entries.
# Column e292 is missing 95 entries.
# Column e293 is missing 95 entries.
# Column e294 is missing 95 entries.
# Column e295 is missing 95 entries.
# Column e296 is missing 95 entries.
# Column e297 is missing 95 entries.
# Column e298 is missing 95 entries.
# Column e299 is missing 95 entries.
# Column e300 is missing 95 entries.
# Column e301 is missing 95 entries.
# Column e302 is missing 95 entries.
# Column e303 is missing 95 entries.
# Column e304 is missing 95 entries.
# Column e305 is missing 95 entries.
# Column e306 is missing 95 entries.
# Column e307 is missing 95 entries.
# Column e308 is missing 95 entries.
# Column e309 is missing 95 entries.
# Column e310 is missing 95 entries.
# Column e311 is missing 95 entries.
# Column e312 is missing 95 entries.
# Column e313 is missing 95 entries.
# Column e314 is missing 95 entries.
# Column e315 is missing 95 entries.
# Column e316 is missing 95 entries.
# Column e317 is missing 95 entries.
# Column e318 is missing 95 entries.
# Column e319 is missing 95 entries.
# Column e320 is missing 95 entries.
# Column e321 is missing 95 entries.
# Column e322 is missing 95 entries.
# Column e323 is missing 95 entries.
# Column e324 is missing 95 entries.
# Column e325 is missing 95 entries.
# Column e326 is missing 95 entries.
# Column e327 is missing 95 entries.
# Column e328 is missing 95 entries.
# Column e329 is missing 95 entries.
# Column e330 is missing 95 entries.
# Column e331 is missing 95 entries.
# Column e332 is missing 95 entries.
# Column e333 is missing 95 entries.
# Column e334 is missing 95 entries.
# Column e335 is missing 95 entries.
# Column e336 is missing 95 entries.
# Column e337 is missing 95 entries.
# Column e338 is missing 95 entries.
# Column e339 is missing 95 entries.
# Column e340 is missing 95 entries.
# Column e341 is missing 95 entries.
# Column e342 is missing 95 entries.
# Column e343 is missing 95 entries.
# Column e344 is missing 95 entries.
# Column e345 is missing 95 entries.
# Column e346 is missing 95 entries.
# Column e347 is missing 95 entries.
# Column e348 is missing 95 entries.
# Column e349 is missing 95 entries.
# Column e350 is missing 95 entries.
# Column e351 is missing 95 entries.
# Column e352 is missing 95 entries.
# Column e353 is missing 95 entries.
# Column e354 is missing 95 entries.
# Column e355 is missing 95 entries.
# Column e356 is missing 95 entries.
# Column e357 is missing 95 entries.
# Column e358 is missing 95 entries.
# Column e359 is missing 95 entries.
# Column e360 is missing 95 entries.
# Column e361 is missing 95 entries.
# Column e362 is missing 95 entries.
# Column e363 is missing 95 entries.
# Column e364 is missing 95 entries.
# Column e365 is missing 95 entries.
# Column e366 is missing 95 entries.
# Column e367 is missing 95 entries.
# Column e368 is missing 95 entries.
# Column e369 is missing 95 entries.
# Column e370 is missing 95 entries.
# Column e371 is missing 95 entries.
# Column e372 is missing 95 entries.
# Column e373 is missing 95 entries.
# Column e374 is missing 95 entries.
# Column e375 is missing 95 entries.
# Column e376 is missing 95 entries.
# Column e377 is missing 95 entries.
# Column e378 is missing 95 entries.
# Column e379 is missing 95 entries.
# Column e380 is missing 95 entries.
# Column e381 is missing 95 entries.
# Column e382 is missing 95 entries.
# Column e383 is missing 95 entries.
# Column e384 is missing 95 entries.
# Column e385 is missing 95 entries.
# Column e386 is missing 95 entries.
# Column e387 is missing 95 entries.
# Column e388 is missing 95 entries.
# Column e389 is missing 95 entries.
# Column e390 is missing 95 entries.
# Column e391 is missing 95 entries.
# Column e392 is missing 95 entries.
# Column e393 is missing 95 entries.
# Column e394 is missing 95 entries.
# Column e395 is missing 95 entries.
# Column e396 is missing 95 entries.
# Column e397 is missing 95 entries.
# Column e398 is missing 95 entries.
# Column e399 is missing 95 entries.
# Column e400 is missing 95 entries.
# Column e401 is missing 95 entries.
# Column e402 is missing 95 entries.
# Column e403 is missing 95 entries.
# Column e404 is missing 95 entries.
# Column e405 is missing 95 entries.
# Column e406 is missing 95 entries.
# Column e407 is missing 95 entries.
# Column e408 is missing 95 entries.
# Column e409 is missing 95 entries.
# Column e410 is missing 95 entries.
# Column e411 is missing 95 entries.
# Column e412 is missing 95 entries.
# Column e413 is missing 95 entries.
# Column e414 is missing 95 entries.
# Column e415 is missing 95 entries.
# Column e416 is missing 95 entries.
# Column e417 is missing 95 entries.
# Column e418 is missing 95 entries.
# Column e419 is missing 95 entries.
# Column e420 is missing 95 entries.
# Column e421 is missing 95 entries.
# Column e422 is missing 95 entries.
# Column e423 is missing 95 entries.
# Column e424 is missing 95 entries.
# Column e425 is missing 95 entries.
# Column e426 is missing 95 entries.
# Column e427 is missing 95 entries.
# Column e428 is missing 95 entries.
# Column e429 is missing 95 entries.
# Column e430 is missing 95 entries.
# Column e431 is missing 95 entries.
# Column e432 is missing 95 entries.
# Column e433 is missing 95 entries.
# Column e434 is missing 95 entries.
# Column e435 is missing 95 entries.
# Column e436 is missing 95 entries.
# Column e437 is missing 95 entries.
# Column e438 is missing 95 entries.
# Column e439 is missing 95 entries.
# Column e440 is missing 95 entries.
# Column e441 is missing 95 entries.
# Column e442 is missing 95 entries.
# Column e443 is missing 95 entries.
# Column e444 is missing 95 entries.
# Column e445 is missing 95 entries.
# Column e446 is missing 95 entries.
# Column e447 is missing 95 entries.
# Column e448 is missing 95 entries.
# Column e449 is missing 95 entries.
# Column e450 is missing 95 entries.
# Column e451 is missing 95 entries.
# Column e452 is missing 95 entries.
# Column e453 is missing 95 entries.
# Column e454 is missing 95 entries.
# Column e455 is missing 95 entries.
# Column e456 is missing 95 entries.
# Column e457 is missing 95 entries.
# Column e458 is missing 95 entries.
# Column e459 is missing 95 entries.
# Column e460 is missing 95 entries.
# Column e461 is missing 95 entries.
# Column e462 is missing 95 entries.
# Column e463 is missing 95 entries.
# Column e464 is missing 95 entries.
# Column e465 is missing 95 entries.
# Column e466 is missing 95 entries.
# Column e467 is missing 95 entries.
# Column e468 is missing 95 entries.
# Column e469 is missing 95 entries.
# Column e470 is missing 95 entries.
# Column e471 is missing 95 entries.
# Column e472 is missing 95 entries.
# Column e473 is missing 95 entries.
# Column e474 is missing 95 entries.
# Column e475 is missing 95 entries.
# Column e476 is missing 95 entries.
# Column e477 is missing 95 entries.
# Column e478 is missing 95 entries.
# Column e479 is missing 95 entries.
# Column e480 is missing 95 entries.
# Column e481 is missing 95 entries.
# Column e482 is missing 95 entries.
# Column e483 is missing 95 entries.
# Column e484 is missing 95 entries.
# Column e485 is missing 95 entries.
# Column e486 is missing 95 entries.
# Column e487 is missing 95 entries.
# Column e488 is missing 95 entries.
# Column e489 is missing 95 entries.
# Column e490 is missing 95 entries.
# Column e491 is missing 95 entries.
# Column e492 is missing 95 entries.
# Column e493 is missing 95 entries.
# Column e494 is missing 95 entries.
# Column e495 is missing 95 entries.
# Column e496 is missing 95 entries.
# Column e497 is missing 95 entries.
# Column e498 is missing 95 entries.
# Column e499 is missing 95 entries.
# Column e500 is missing 95 entries.
# Column e501 is missing 95 entries.
# Column e502 is missing 95 entries.
# Column e503 is missing 95 entries.
# Column e504 is missing 95 entries.
# Column e505 is missing 95 entries.
# Column e506 is missing 95 entries.
# Column e507 is missing 95 entries.
# Column e508 is missing 95 entries.
# Column e509 is missing 95 entries.
# Column e510 is missing 95 entries.
# Column e511 is missing 95 entries.
# Column e512 is missing 95 entries.
# Column e513 is missing 95 entries.
# Column e514 is missing 95 entries.
# Column e515 is missing 95 entries.
# Column e516 is missing 95 entries.
# Column e517 is missing 95 entries.
# Column e518 is missing 95 entries.
# Column e519 is missing 95 entries.
# Column e520 is missing 95 entries.
# Column e521 is missing 95 entries.
# Column e522 is missing 95 entries.
# Column e523 is missing 95 entries.
# Column e524 is missing 95 entries.
# Column e525 is missing 95 entries.
# Column e526 is missing 95 entries.
# Column e527 is missing 95 entries.
# Column e528 is missing 95 entries.
# Column e529 is missing 95 entries.
# Column e530 is missing 95 entries.
# Column e531 is missing 95 entries.
# Column e532 is missing 95 entries.
# Column e533 is missing 95 entries.
# Column e534 is missing 95 entries.
# Column e535 is missing 95 entries.
# Column e536 is missing 95 entries.
# Column e537 is missing 95 entries.
# Column e538 is missing 95 entries.
# Column e539 is missing 95 entries.
# Column e540 is missing 95 entries.
# Column e541 is missing 95 entries.
# Column e542 is missing 95 entries.
# Column e543 is missing 95 entries.
# Column e544 is missing 95 entries.
# Column e545 is missing 95 entries.
# Column e546 is missing 95 entries.
# Column e547 is missing 95 entries.
# Column e548 is missing 95 entries.
# Column e549 is missing 95 entries.
# Column e550 is missing 95 entries.
# Column e551 is missing 95 entries.
# Column e552 is missing 95 entries.
# Column e553 is missing 95 entries.
# Column e554 is missing 95 entries.
# Column e555 is missing 95 entries.
# Column e556 is missing 95 entries.
# Column e557 is missing 95 entries.
# Column e558 is missing 95 entries.
# Column e559 is missing 95 entries.
# Column e560 is missing 95 entries.
# Column e561 is missing 95 entries.
# Column e562 is missing 95 entries.
# Column e563 is missing 95 entries.
# Column e564 is missing 95 entries.
# Column e565 is missing 95 entries.
# Column e566 is missing 95 entries.
# Column e567 is missing 95 entries.
# Column e568 is missing 95 entries.
# Column e569 is missing 95 entries.
# Column e570 is missing 95 entries.
# Column e571 is missing 95 entries.
# Column e572 is missing 95 entries.
# Column e573 is missing 95 entries.
# Column e574 is missing 95 entries.
# Column e575 is missing 95 entries.
# Column e576 is missing 95 entries.
# Column e577 is missing 95 entries.
# Column e578 is missing 95 entries.
# Column e579 is missing 95 entries.
# Column e580 is missing 95 entries.
# Column e581 is missing 95 entries.
# Column e582 is missing 95 entries.
# Column e583 is missing 95 entries.
# Column e584 is missing 95 entries.
# Column e585 is missing 95 entries.
# Column e586 is missing 95 entries.
# Column e587 is missing 95 entries.
# Column e588 is missing 95 entries.
# Column e589 is missing 95 entries.
# Column e590 is missing 95 entries.
# Column e591 is missing 95 entries.
# Column e592 is missing 95 entries.
# Column e593 is missing 95 entries.
# Column e594 is missing 95 entries.
# Column e595 is missing 95 entries.
# Column e596 is missing 95 entries.
# Column e597 is missing 95 entries.
# Column e598 is missing 95 entries.
# Column e599 is missing 95 entries.
# Column e600 is missing 95 entries.
# Column e601 is missing 95 entries.
# Column e602 is missing 95 entries.
# Column e603 is missing 95 entries.
# Column e604 is missing 95 entries.
# Column e605 is missing 95 entries.
# Column e606 is missing 95 entries.
# Column e607 is missing 95 entries.
# Column e608 is missing 95 entries.
# Column e609 is missing 95 entries.
# Column e610 is missing 95 entries.
# Column e611 is missing 95 entries.
# Column e612 is missing 95 entries.
# Column e613 is missing 95 entries.
# Column e614 is missing 95 entries.
# Column e615 is missing 95 entries.
# Column e616 is missing 95 entries.
# Column e617 is missing 95 entries.
# Column e618 is missing 95 entries.
# Column e619 is missing 95 entries.
# Column e620 is missing 95 entries.
# Column e621 is missing 95 entries.
# Column e622 is missing 95 entries.
# Column e623 is missing 95 entries.
# Column e624 is missing 95 entries.
# Column e625 is missing 95 entries.
# Column e626 is missing 95 entries.
# Column e627 is missing 95 entries.
# Column e628 is missing 95 entries.
# Column e629 is missing 95 entries.
# Column e630 is missing 95 entries.
# Column e631 is missing 95 entries.
# Column e632 is missing 95 entries.
# Column e633 is missing 95 entries.
# Column e634 is missing 95 entries.
# Column e635 is missing 95 entries.
# Column e636 is missing 95 entries.
# Column e637 is missing 95 entries.
# Column e638 is missing 95 entries.
# Column e639 is missing 95 entries.
# Column e640 is missing 95 entries.
# Column e641 is missing 95 entries.
# Column e642 is missing 95 entries.
# Column e643 is missing 95 entries.
# Column e644 is missing 95 entries.
# Column e645 is missing 95 entries.
# Column e646 is missing 95 entries.
# Column e647 is missing 95 entries.
# Column e648 is missing 95 entries.
# Column e649 is missing 95 entries.
# Column e650 is missing 95 entries.
# Column e651 is missing 95 entries.
# Column e652 is missing 95 entries.
# Column e653 is missing 95 entries.
# Column e654 is missing 95 entries.
# Column e655 is missing 95 entries.
# Column e656 is missing 95 entries.
# Column e657 is missing 95 entries.
# Column e658 is missing 95 entries.
# Column e659 is missing 95 entries.
# Column e660 is missing 95 entries.
# Column e661 is missing 95 entries.
# Column e662 is missing 95 entries.
# Column e663 is missing 95 entries.
# Column e664 is missing 95 entries.
# Column e665 is missing 95 entries.
# Column e666 is missing 95 entries.
# Column e667 is missing 95 entries.
# Column e668 is missing 95 entries.
# Column e669 is missing 95 entries.
# Column e670 is missing 95 entries.
# Column e671 is missing 95 entries.
# Column e672 is missing 95 entries.
# Column e673 is missing 95 entries.
# Column e674 is missing 95 entries.
# Column e675 is missing 95 entries.
# Column e676 is missing 95 entries.
# Column e677 is missing 95 entries.
# Column e678 is missing 95 entries.
# Column e679 is missing 95 entries.
# Column e680 is missing 95 entries.
# Column e681 is missing 95 entries.
# Column e682 is missing 95 entries.
# Column e683 is missing 95 entries.
# Column e684 is missing 95 entries.
# Column e685 is missing 95 entries.
# Column e686 is missing 95 entries.
# Column e687 is missing 95 entries.
# Column e688 is missing 95 entries.
# Column e689 is missing 95 entries.
# Column e690 is missing 95 entries.
# Column e691 is missing 95 entries.
# Column e692 is missing 95 entries.
# Column e693 is missing 95 entries.
# Column e694 is missing 95 entries.
# Column e695 is missing 95 entries.
# Column e696 is missing 95 entries.
# Column e697 is missing 95 entries.
# Column e698 is missing 95 entries.
# Column e699 is missing 95 entries.
# Column e700 is missing 95 entries.
# Column e701 is missing 95 entries.
# Column e702 is missing 95 entries.
# Column e703 is missing 95 entries.
# Column e704 is missing 95 entries.
# Column e705 is missing 95 entries.
# Column e706 is missing 95 entries.
# Column e707 is missing 95 entries.
# Column e708 is missing 95 entries.
# Column e709 is missing 95 entries.
# Column e710 is missing 95 entries.
# Column e711 is missing 95 entries.
# Column e712 is missing 95 entries.
# Column e713 is missing 95 entries.
# Column e714 is missing 95 entries.
# Column e715 is missing 95 entries.
# Column e716 is missing 95 entries.
# Column e717 is missing 95 entries.
# Column e718 is missing 95 entries.
# Column e719 is missing 95 entries.
# Column e720 is missing 95 entries.
# Column e721 is missing 95 entries.
# Column e722 is missing 95 entries.
# Column e723 is missing 95 entries.
# Column e724 is missing 95 entries.
# Column e725 is missing 95 entries.
# Column e726 is missing 95 entries.
# Column e727 is missing 95 entries.
# Column e728 is missing 95 entries.
# Column e729 is missing 95 entries.
# Column e730 is missing 95 entries.
# Column e731 is missing 95 entries.
# Column e732 is missing 95 entries.
# Column e733 is missing 95 entries.
# Column e734 is missing 95 entries.
# Column e735 is missing 95 entries.
# Column e736 is missing 95 entries.
# Column e737 is missing 95 entries.
# Column e738 is missing 95 entries.
# Column e739 is missing 95 entries.
# Column e740 is missing 95 entries.
# Column e741 is missing 95 entries.
# Column e742 is missing 95 entries.
# Column e743 is missing 95 entries.
# Column e744 is missing 95 entries.
# Column e745 is missing 95 entries.
# Column e746 is missing 95 entries.
# Column e747 is missing 95 entries.
# Column e748 is missing 95 entries.
# Column e749 is missing 95 entries.
# Column e750 is missing 95 entries.
# Column e751 is missing 95 entries.
# Column e752 is missing 95 entries.
# Column e753 is missing 95 entries.
# Column e754 is missing 95 entries.
# Column e755 is missing 95 entries.
# Column e756 is missing 95 entries.
# Column e757 is missing 95 entries.
# Column e758 is missing 95 entries.
# Column e759 is missing 95 entries.
# Column e760 is missing 95 entries.
# Column e761 is missing 95 entries.
# Column e762 is missing 95 entries.
# Column e763 is missing 95 entries.
# Column e764 is missing 95 entries.
# Column e765 is missing 95 entries.
# Column e766 is missing 95 entries.
# Column e767 is missing 95 entries.
# Column e768 is missing 95 entries.
# Column e769 is missing 95 entries.
# Column e770 is missing 95 entries.
# Column e771 is missing 95 entries.
# Column e772 is missing 95 entries.
# Column e773 is missing 95 entries.
# Column e774 is missing 95 entries.
# Column e775 is missing 95 entries.
# Column e776 is missing 95 entries.
# Column e777 is missing 95 entries.
# Column e778 is missing 95 entries.
# Column e779 is missing 95 entries.
# Column e780 is missing 95 entries.
# Column e781 is missing 95 entries.
# Column e782 is missing 95 entries.
# Column e783 is missing 95 entries.
# Column e784 is missing 95 entries.
# Column e785 is missing 95 entries.
# Column e786 is missing 95 entries.
# Column e787 is missing 95 entries.
# Column e788 is missing 95 entries.
# Column e789 is missing 95 entries.
# Column e790 is missing 95 entries.
# Column e791 is missing 95 entries.
# Column e792 is missing 95 entries.
# Column e793 is missing 95 entries.
# Column e794 is missing 95 entries.
# Column e795 is missing 95 entries.
# Column e796 is missing 95 entries.
# Column e797 is missing 95 entries.
# Column e798 is missing 95 entries.
# Column e799 is missing 95 entries.
# Column e800 is missing 95 entries.
# Column e801 is missing 95 entries.
# Column e802 is missing 95 entries.
# Column e803 is missing 95 entries.
# Column e804 is missing 95 entries.
# Column e805 is missing 95 entries.
# Column e806 is missing 95 entries.
# Column e807 is missing 95 entries.
# Column e808 is missing 95 entries.
# Column e809 is missing 95 entries.
# Column e810 is missing 95 entries.
# Column e811 is missing 95 entries.
# Column e812 is missing 95 entries.
# Column e813 is missing 95 entries.
# Column e814 is missing 95 entries.
# Column e815 is missing 95 entries.
# Column e816 is missing 95 entries.
# Column e817 is missing 95 entries.
# Column e818 is missing 95 entries.
# Column e819 is missing 95 entries.
# Column e820 is missing 95 entries.
# Column e821 is missing 95 entries.
# Column e822 is missing 95 entries.
# Column e823 is missing 95 entries.
# Column e824 is missing 95 entries.
# Column e825 is missing 95 entries.
# Column e826 is missing 95 entries.
# Column e827 is missing 95 entries.
# Column e828 is missing 95 entries.
# Column e829 is missing 95 entries.
# Column e830 is missing 95 entries.
# Column e831 is missing 95 entries.
# Column e832 is missing 95 entries.
# Column e833 is missing 95 entries.
# Column e834 is missing 95 entries.
# Column e835 is missing 95 entries.
# Column e836 is missing 95 entries.
# Column e837 is missing 95 entries.
# Column e838 is missing 95 entries.
# Column e839 is missing 95 entries.
# Column e840 is missing 95 entries.
# Column e841 is missing 95 entries.
# Column e842 is missing 95 entries.
# Column e843 is missing 95 entries.
# Column e844 is missing 95 entries.
# Column e845 is missing 95 entries.
# Column e846 is missing 95 entries.
# Column e847 is missing 95 entries.
# Column e848 is missing 95 entries.
# Column e849 is missing 95 entries.
# Column e850 is missing 95 entries.
# Column e851 is missing 95 entries.
# Column e852 is missing 95 entries.
# Column e853 is missing 95 entries.
# Column e854 is missing 95 entries.
# Column e855 is missing 95 entries.
# Column e856 is missing 95 entries.
# Column e857 is missing 95 entries.
# Column e858 is missing 95 entries.
# Column e859 is missing 95 entries.
# Column e860 is missing 95 entries.
# Column e861 is missing 95 entries.
# Column e862 is missing 95 entries.
# Column e863 is missing 95 entries.
# Column e864 is missing 95 entries.
# Column e865 is missing 95 entries.
# Column e866 is missing 95 entries.
# Column e867 is missing 95 entries.
# Column e868 is missing 95 entries.
# Column e869 is missing 95 entries.
# Column e870 is missing 95 entries.
# Column e871 is missing 95 entries.
# Column e872 is missing 95 entries.
# Column e873 is missing 95 entries.
# Column e874 is missing 95 entries.
# Column e875 is missing 95 entries.
# Column e876 is missing 95 entries.
# Column e877 is missing 95 entries.
# Column e878 is missing 95 entries.
# Column e879 is missing 95 entries.
# Column e880 is missing 95 entries.
# Column e881 is missing 95 entries.
# Column e882 is missing 95 entries.
# Column e883 is missing 95 entries.
# Column e884 is missing 95 entries.
# Column e885 is missing 95 entries.
# Column e886 is missing 95 entries.
# Column e887 is missing 95 entries.
# Column e888 is missing 95 entries.
# Column e889 is missing 95 entries.
# Column e890 is missing 95 entries.
# Column e891 is missing 95 entries.
# Column e892 is missing 95 entries.
# Column e893 is missing 95 entries.
# Column e894 is missing 95 entries.
# Column e895 is missing 95 entries.
# Column e896 is missing 95 entries.
# Column e897 is missing 95 entries.
# Column e898 is missing 95 entries.
# Column e899 is missing 95 entries.
# Column e900 is missing 95 entries.
# Column e901 is missing 95 entries.
# Column e902 is missing 95 entries.
# Column e903 is missing 95 entries.
# Column e904 is missing 95 entries.
# Column e905 is missing 95 entries.
# Column e906 is missing 95 entries.
# Column e907 is missing 95 entries.
# Column e908 is missing 95 entries.
# Column e909 is missing 95 entries.
# Column e910 is missing 95 entries.
# Column e911 is missing 95 entries.
# Column e912 is missing 95 entries.
# Column e913 is missing 95 entries.
# Column e914 is missing 95 entries.
# Column e915 is missing 95 entries.
# Column e916 is missing 95 entries.
# Column e917 is missing 95 entries.
# Column e918 is missing 95 entries.
# Column e919 is missing 95 entries.
# Column e920 is missing 95 entries.
# Column e921 is missing 95 entries.
# Column e922 is missing 95 entries.
# Column e923 is missing 95 entries.
# Column e924 is missing 95 entries.
# Column e925 is missing 95 entries.
# Column e926 is missing 95 entries.
# Column e927 is missing 95 entries.
# Column e928 is missing 95 entries.
# Column e929 is missing 95 entries.
# Column e930 is missing 95 entries.
# Column e931 is missing 95 entries.
# Column e932 is missing 95 entries.
# Column e933 is missing 95 entries.
# Column e934 is missing 95 entries.
# Column e935 is missing 95 entries.
# Column e936 is missing 95 entries.
# Column e937 is missing 95 entries.
# Column e938 is missing 95 entries.
# Column e939 is missing 95 entries.
# Column e940 is missing 95 entries.
# Column e941 is missing 95 entries.
# Column e942 is missing 95 entries.
# Column e943 is missing 95 entries.
# Column e944 is missing 95 entries.
# Column e945 is missing 95 entries.
# Column e946 is missing 95 entries.
# Column e947 is missing 95 entries.
# Column e948 is missing 95 entries.
# Column e949 is missing 95 entries.
# Column e950 is missing 95 entries.
# Column e951 is missing 95 entries.
# Column e952 is missing 95 entries.
# Column e953 is missing 95 entries.
# Column e954 is missing 95 entries.
# Column e955 is missing 95 entries.
# Column e956 is missing 95 entries.
# Column e957 is missing 95 entries.
# Column e958 is missing 95 entries.
# Column e959 is missing 95 entries.
# Column e960 is missing 95 entries.
# Column e961 is missing 95 entries.
# Column e962 is missing 95 entries.
# Column e963 is missing 95 entries.
# Column e964 is missing 95 entries.
# Column e965 is missing 95 entries.
# Column e966 is missing 95 entries.
# Column e967 is missing 95 entries.
# Column e968 is missing 95 entries.
# Column e969 is missing 95 entries.
# Column e970 is missing 95 entries.
# Column e971 is missing 95 entries.
# Column e972 is missing 95 entries.
# Column e973 is missing 95 entries.
# Column e974 is missing 95 entries.
# Column e975 is missing 95 entries.
# Column e976 is missing 95 entries.
# Column e977 is missing 95 entries.
# Column e978 is missing 95 entries.
# Column e979 is missing 95 entries.
# Column e980 is missing 95 entries.
# Column e981 is missing 95 entries.
# Column e982 is missing 95 entries.
# Column e983 is missing 95 entries.
# Column e984 is missing 95 entries.
# Column e985 is missing 95 entries.
# Column e986 is missing 95 entries.
# Column e987 is missing 95 entries.
# Column e988 is missing 95 entries.
# Column e989 is missing 95 entries.
# Column e990 is missing 95 entries.
# Column e991 is missing 95 entries.
# Column e992 is missing 95 entries.
# Column e993 is missing 95 entries.
# Column e994 is missing 95 entries.
# Column e995 is missing 95 entries.
# Column e996 is missing 95 entries.
# Column e997 is missing 95 entries.
# Column e998 is missing 95 entries.
# Column e999 is missing 95 entries.
# Column e1000 is missing 95 entries.
# Column e1001 is missing 95 entries.
# Column e1002 is missing 95 entries.
# Column e1003 is missing 95 entries.
# Column e1004 is missing 95 entries.
# Column e1005 is missing 95 entries.
# Column e1006 is missing 95 entries.
# Column e1007 is missing 95 entries.
# Column e1008 is missing 95 entries.
# Column e1009 is missing 95 entries.
# Column e1010 is missing 95 entries.
# Column e1011 is missing 95 entries.
# Column e1012 is missing 95 entries.
# Column e1013 is missing 95 entries.
# Column e1014 is missing 95 entries.
# Column e1015 is missing 95 entries.
# Column e1016 is missing 95 entries.
# Column e1017 is missing 95 entries.
# Column e1018 is missing 95 entries.
# Column e1019 is missing 95 entries.
# Column e1020 is missing 95 entries.
# Column e1021 is missing 95 entries.
# Column e1022 is missing 95 entries.
# Column e1023 is missing 95 entries.
# Column e1024 is missing 95 entries.
# Column e1025 is missing 95 entries.
# Column e1026 is missing 95 entries.
# Column e1027 is missing 95 entries.
# Column e1028 is missing 95 entries.
# Column e1029 is missing 95 entries.
# Column e1030 is missing 95 entries.
# Column e1031 is missing 95 entries.
# Column e1032 is missing 95 entries.
# Column e1033 is missing 95 entries.
# Column e1034 is missing 95 entries.
# Column e1035 is missing 95 entries.
# Column e1036 is missing 95 entries.
# Column e1037 is missing 95 entries.
# Column e1038 is missing 95 entries.
# Column e1039 is missing 95 entries.
# Column e1040 is missing 95 entries.
# Column e1041 is missing 95 entries.
# Column e1042 is missing 95 entries.
# Column e1043 is missing 95 entries.
# Column e1044 is missing 95 entries.
# Column e1045 is missing 95 entries.
# Column e1046 is missing 95 entries.
# Column e1047 is missing 95 entries.
# Column e1048 is missing 95 entries.
# Column e1049 is missing 95 entries.
# Column e1050 is missing 95 entries.
# Column e1051 is missing 95 entries.
# Column e1052 is missing 95 entries.
# Column e1053 is missing 95 entries.
# Column e1054 is missing 95 entries.
# Column e1055 is missing 95 entries.
# Column e1056 is missing 95 entries.
# Column e1057 is missing 95 entries.
# Column e1058 is missing 95 entries.
# Column e1059 is missing 95 entries.
# Column e1060 is missing 95 entries.
# Column e1061 is missing 95 entries.
# Column e1062 is missing 95 entries.
# Column e1063 is missing 95 entries.
# Column e1064 is missing 95 entries.
# Column e1065 is missing 95 entries.
# Column e1066 is missing 95 entries.
# Column e1067 is missing 95 entries.
# Column e1068 is missing 95 entries.
# Column e1069 is missing 95 entries.
# Column e1070 is missing 95 entries.
# Column e1071 is missing 95 entries.
# Column e1072 is missing 95 entries.
# Column e1073 is missing 95 entries.
# Column e1074 is missing 95 entries.
# Column e1075 is missing 95 entries.
# Column e1076 is missing 95 entries.
# Column e1077 is missing 95 entries.
# Column e1078 is missing 95 entries.
# Column e1079 is missing 95 entries.
# Column e1080 is missing 95 entries.
# Column e1081 is missing 95 entries.
# Column e1082 is missing 95 entries.
# Column e1083 is missing 95 entries.
# Column e1084 is missing 95 entries.
# Column e1085 is missing 95 entries.
# Column e1086 is missing 95 entries.
# Column e1087 is missing 95 entries.
# Column e1088 is missing 95 entries.
# Column e1089 is missing 95 entries.
# Column e1090 is missing 95 entries.
# Column e1091 is missing 95 entries.
# Column e1092 is missing 95 entries.
# Column e1093 is missing 95 entries.
# Column e1094 is missing 95 entries.
# Column e1095 is missing 95 entries.
# Column e1096 is missing 95 entries.
# Column e1097 is missing 95 entries.
# Column e1098 is missing 95 entries.
# Column e1099 is missing 95 entries.
# Column e1100 is missing 95 entries.
# Column e1101 is missing 95 entries.
# Column e1102 is missing 95 entries.
# Column e1103 is missing 95 entries.
# Column e1104 is missing 95 entries.
# Column e1105 is missing 95 entries.
# Column e1106 is missing 95 entries.
# Column e1107 is missing 95 entries.
# Column e1108 is missing 95 entries.
# Column e1109 is missing 95 entries.
# Column e1110 is missing 95 entries.
# Column e1111 is missing 95 entries.
# Column e1112 is missing 95 entries.
# Column e1113 is missing 95 entries.
# Column e1114 is missing 95 entries.
# Column e1115 is missing 95 entries.
# Column e1116 is missing 95 entries.
# Column e1117 is missing 95 entries.
# Column e1118 is missing 95 entries.
# Column e1119 is missing 95 entries.
# Column e1120 is missing 95 entries.
# Column e1121 is missing 95 entries.
# Column e1122 is missing 95 entries.
# Column e1123 is missing 95 entries.
# Column e1124 is missing 95 entries.
# Column e1125 is missing 95 entries.
# Column e1126 is missing 95 entries.
# Column e1127 is missing 95 entries.
# Column e1128 is missing 95 entries.
# Column e1129 is missing 95 entries.
# Column e1130 is missing 95 entries.
# Column e1131 is missing 95 entries.
# Column e1132 is missing 95 entries.
# Column e1133 is missing 95 entries.
# Column e1134 is missing 95 entries.
# Column e1135 is missing 95 entries.
# Column e1136 is missing 95 entries.
# Column e1137 is missing 95 entries.
# Column e1138 is missing 95 entries.
# Column e1139 is missing 95 entries.
# Column e1140 is missing 95 entries.
# Column e1141 is missing 95 entries.
# Column e1142 is missing 95 entries.
# Column e1143 is missing 95 entries.
# Column e1144 is missing 95 entries.
# Column e1145 is missing 95 entries.
# Column e1146 is missing 95 entries.
# Column e1147 is missing 95 entries.
# Column e1148 is missing 95 entries.
# Column e1149 is missing 95 entries.
# Column e1150 is missing 95 entries.
# Column e1151 is missing 95 entries.
# Column e1152 is missing 95 entries.
# Column e1153 is missing 95 entries.
# Column e1154 is missing 95 entries.
# Column e1155 is missing 95 entries.
# Column e1156 is missing 95 entries.
# Column e1157 is missing 95 entries.
# Column e1158 is missing 95 entries.
# Column e1159 is missing 95 entries.
# Column e1160 is missing 95 entries.
# Column e1161 is missing 95 entries.
# Column e1162 is missing 95 entries.
# Column e1163 is missing 95 entries.
# Column e1164 is missing 95 entries.
# Column e1165 is missing 95 entries.
# Column e1166 is missing 95 entries.
# Column e1167 is missing 95 entries.
# Column e1168 is missing 95 entries.
# Column e1169 is missing 95 entries.
# Column e1170 is missing 95 entries.
# Column e1171 is missing 95 entries.
# Column e1172 is missing 95 entries.
# Column e1173 is missing 95 entries.
# Column e1174 is missing 95 entries.
# Column e1175 is missing 95 entries.
# Column e1176 is missing 95 entries.
# Column e1177 is missing 95 entries.
# Column e1178 is missing 95 entries.
# Column e1179 is missing 95 entries.
# Column e1180 is missing 95 entries.
# Column e1181 is missing 95 entries.
# Column e1182 is missing 95 entries.
# Column e1183 is missing 95 entries.
# Column e1184 is missing 95 entries.
# Column e1185 is missing 95 entries.
# Column e1186 is missing 95 entries.
# Column e1187 is missing 95 entries.
# Column e1188 is missing 95 entries.
# Column e1189 is missing 95 entries.
# Column e1190 is missing 95 entries.
# Column e1191 is missing 95 entries.
# Column e1192 is missing 95 entries.
# Column e1193 is missing 95 entries.
# Column e1194 is missing 95 entries.
# Column e1195 is missing 95 entries.
# Column e1196 is missing 95 entries.
# Column e1197 is missing 95 entries.
# Column e1198 is missing 95 entries.
# Column e1199 is missing 95 entries.
# Column e1200 is missing 95 entries.
# Column e1201 is missing 95 entries.
# Column e1202 is missing 95 entries.
# Column e1203 is missing 95 entries.
# Column e1204 is missing 95 entries.
# Column e1205 is missing 95 entries.
# Column e1206 is missing 95 entries.
# Column e1207 is missing 95 entries.
# Column e1208 is missing 95 entries.
# Column e1209 is missing 95 entries.
# Column e1210 is missing 95 entries.
# Column e1211 is missing 95 entries.
# Column e1212 is missing 95 entries.
# Column e1213 is missing 95 entries.
# Column e1214 is missing 95 entries.
# Column e1215 is missing 95 entries.
# Column e1216 is missing 95 entries.
# Column e1217 is missing 95 entries.
# Column e1218 is missing 95 entries.
# Column e1219 is missing 95 entries.
# Column e1220 is missing 95 entries.
# Column e1221 is missing 95 entries.
# Column e1222 is missing 95 entries.
# Column e1223 is missing 95 entries.
# Column e1224 is missing 95 entries.
# Column e1225 is missing 95 entries.
# Column e1226 is missing 95 entries.
# Column e1227 is missing 95 entries.
# Column e1228 is missing 95 entries.
# Column e1229 is missing 95 entries.
# Column e1230 is missing 95 entries.
# Column e1231 is missing 95 entries.
# Column e1232 is missing 95 entries.
# Column e1233 is missing 95 entries.
# Column e1234 is missing 95 entries.
# Column e1235 is missing 95 entries.
# Column e1236 is missing 95 entries.
# Column e1237 is missing 95 entries.
# Column e1238 is missing 95 entries.
# Column e1239 is missing 95 entries.
# Column e1240 is missing 95 entries.
# Column e1241 is missing 95 entries.
# Column e1242 is missing 95 entries.
# Column e1243 is missing 95 entries.
# Column e1244 is missing 95 entries.
# Column e1245 is missing 95 entries.
# Column e1246 is missing 95 entries.
# Column e1247 is missing 95 entries.
# Column e1248 is missing 95 entries.
# Column e1249 is missing 95 entries.
# Column e1250 is missing 95 entries.
# Column e1251 is missing 95 entries.
# Column e1252 is missing 95 entries.
# Column e1253 is missing 95 entries.
# Column e1254 is missing 95 entries.
# Column e1255 is missing 95 entries.
# Column e1256 is missing 95 entries.
# Column e1257 is missing 95 entries.
# Column e1258 is missing 95 entries.
# Column e1259 is missing 95 entries.
# Column e1260 is missing 95 entries.
# Column e1261 is missing 95 entries.
# Column e1262 is missing 95 entries.
# Column e1263 is missing 95 entries.
# Column e1264 is missing 95 entries.
# Column e1265 is missing 95 entries.
# Column e1266 is missing 95 entries.
# Column e1267 is missing 95 entries.
# Column e1268 is missing 95 entries.
# Column e1269 is missing 95 entries.
# Column e1270 is missing 95 entries.
# Column e1271 is missing 95 entries.
# Column e1272 is missing 95 entries.
# Column e1273 is missing 95 entries.
# Column e1274 is missing 95 entries.
# Column e1275 is missing 95 entries.
# Column e1276 is missing 95 entries.
# Column e1277 is missing 95 entries.
# Column e1278 is missing 95 entries.
# Column e1279 is missing 95 entries.
# Column e1280 is missing 95 entries.
# Column e1281 is missing 95 entries.
# Column e1282 is missing 95 entries.
# Column e1283 is missing 95 entries.
# Column e1284 is missing 95 entries.
# Column e1285 is missing 95 entries.
# Column e1286 is missing 95 entries.
# Column e1287 is missing 95 entries.
# Column e1288 is missing 95 entries.
# Column e1289 is missing 95 entries.
# Column e1290 is missing 95 entries.
# Column e1291 is missing 95 entries.
# Column e1292 is missing 95 entries.
# Column e1293 is missing 95 entries.
# Column e1294 is missing 95 entries.
# Column e1295 is missing 95 entries.
# Column e1296 is missing 95 entries.
# Column e1297 is missing 95 entries.
# Column e1298 is missing 95 entries.
# Column e1299 is missing 95 entries.
# Column e1300 is missing 95 entries.
# Column e1301 is missing 95 entries.
# Column e1302 is missing 95 entries.
# Column e1303 is missing 95 entries.
# Column e1304 is missing 95 entries.
# Column e1305 is missing 95 entries.
# Column e1306 is missing 95 entries.
# Column e1307 is missing 95 entries.
# Column e1308 is missing 95 entries.
# Column e1309 is missing 95 entries.
# Column e1310 is missing 95 entries.
# Column e1311 is missing 95 entries.
# Column e1312 is missing 95 entries.
# Column e1313 is missing 95 entries.
# Column e1314 is missing 95 entries.
# Column e1315 is missing 95 entries.
# Column e1316 is missing 95 entries.
# Column e1317 is missing 95 entries.
# Column e1318 is missing 95 entries.
# Column e1319 is missing 95 entries.
# Column e1320 is missing 95 entries.
# Column e1321 is missing 95 entries.
# Column e1322 is missing 95 entries.
# Column e1323 is missing 95 entries.
# Column e1324 is missing 95 entries.
# Column e1325 is missing 95 entries.
# Column e1326 is missing 95 entries.
# Column e1327 is missing 95 entries.
# Column e1328 is missing 95 entries.
# Column e1329 is missing 95 entries.
# Column e1330 is missing 95 entries.
# Column e1331 is missing 95 entries.
# Column e1332 is missing 95 entries.
# Column e1333 is missing 95 entries.
# Column e1334 is missing 95 entries.
# Column e1335 is missing 95 entries.
# Column e1336 is missing 95 entries.
# Column e1337 is missing 95 entries.
# Column e1338 is missing 95 entries.
# Column e1339 is missing 95 entries.
# Column e1340 is missing 95 entries.
# Column e1341 is missing 95 entries.
# Column e1342 is missing 95 entries.
# Column e1343 is missing 95 entries.
# Column e1344 is missing 95 entries.
# Column e1345 is missing 95 entries.
# Column e1346 is missing 95 entries.
# Column e1347 is missing 95 entries.
# Column e1348 is missing 95 entries.
# Column e1349 is missing 95 entries.
# Column e1350 is missing 95 entries.
# Column e1351 is missing 95 entries.
# Column e1352 is missing 95 entries.
# Column e1353 is missing 95 entries.
# Column e1354 is missing 95 entries.
# Column e1355 is missing 95 entries.
# Column e1356 is missing 95 entries.
# Column e1357 is missing 95 entries.
# Column e1358 is missing 95 entries.
# Column e1359 is missing 95 entries.
# Column e1360 is missing 95 entries.
# Column e1361 is missing 95 entries.
# Column e1362 is missing 95 entries.
# Column e1363 is missing 95 entries.
# Column e1364 is missing 95 entries.
# Column e1365 is missing 95 entries.
# Column e1366 is missing 95 entries.
# Column e1367 is missing 95 entries.
# Column e1368 is missing 95 entries.
# Column e1369 is missing 95 entries.
# Column e1370 is missing 95 entries.
# Column e1371 is missing 95 entries.
# Column e1372 is missing 95 entries.
# Column e1373 is missing 95 entries.
# Column e1374 is missing 95 entries.
# Column e1375 is missing 95 entries.
# Column e1376 is missing 95 entries.
# Column e1377 is missing 95 entries.
# Column e1378 is missing 95 entries.
# Column e1379 is missing 95 entries.
# Column e1380 is missing 95 entries.
# Column e1381 is missing 95 entries.
# Column e1382 is missing 95 entries.
# Column e1383 is missing 95 entries.
# Column e1384 is missing 95 entries.
# Column e1385 is missing 95 entries.
# Column e1386 is missing 95 entries.
# Column e1387 is missing 95 entries.
# Column e1388 is missing 95 entries.
# Column e1389 is missing 95 entries.
# Column e1390 is missing 95 entries.
# Column e1391 is missing 95 entries.
# Column e1392 is missing 95 entries.
# Column e1393 is missing 95 entries.
# Column e1394 is missing 95 entries.
# Column e1395 is missing 95 entries.
# Column e1396 is missing 95 entries.
# Column e1397 is missing 95 entries.
# Column e1398 is missing 95 entries.
# Column e1399 is missing 95 entries.
# Column e1400 is missing 95 entries.
# Column e1401 is missing 95 entries.
# Column e1402 is missing 95 entries.
# Column e1403 is missing 95 entries.
# Column e1404 is missing 95 entries.
# Column e1405 is missing 95 entries.
# Column e1406 is missing 95 entries.
# Column e1407 is missing 95 entries.
# Column e1408 is missing 95 entries.
# Column e1409 is missing 95 entries.
# Column e1410 is missing 95 entries.
# Column e1411 is missing 95 entries.
# Column e1412 is missing 95 entries.
# Column e1413 is missing 95 entries.
# Column e1414 is missing 95 entries.
# Column e1415 is missing 95 entries.
# Column e1416 is missing 95 entries.
# Column e1417 is missing 95 entries.
# Column e1418 is missing 95 entries.
# Column e1419 is missing 95 entries.
# Column e1420 is missing 95 entries.
# Column e1421 is missing 95 entries.
# Column e1422 is missing 95 entries.
# Column e1423 is missing 95 entries.
# Column e1424 is missing 95 entries.
# Column e1425 is missing 95 entries.
# Column e1426 is missing 95 entries.
# Column e1427 is missing 95 entries.
# Column e1428 is missing 95 entries.
# Column e1429 is missing 95 entries.
# Column e1430 is missing 95 entries.
# Column e1431 is missing 95 entries.
# Column e1432 is missing 95 entries.
# Column e1433 is missing 95 entries.
# Column e1434 is missing 95 entries.
# Column e1435 is missing 95 entries.
# Column e1436 is missing 95 entries.
# Column e1437 is missing 95 entries.
# Column e1438 is missing 95 entries.
# Column e1439 is missing 95 entries.
# Column e1440 is missing 95 entries.
# Column e1441 is missing 95 entries.
# Column e1442 is missing 95 entries.
# Column e1443 is missing 95 entries.
# Column e1444 is missing 95 entries.
# Column e1445 is missing 95 entries.
# Column e1446 is missing 95 entries.
# Column e1447 is missing 95 entries.
# Column e1448 is missing 95 entries.
# Column e1449 is missing 95 entries.
# Column e1450 is missing 95 entries.
# Column e1451 is missing 95 entries.
# Column e1452 is missing 95 entries.
# Column e1453 is missing 95 entries.
# Column e1454 is missing 95 entries.
# Column e1455 is missing 95 entries.
# Column e1456 is missing 95 entries.
# Column e1457 is missing 95 entries.
# Column e1458 is missing 95 entries.
# Column e1459 is missing 95 entries.
# Column e1460 is missing 95 entries.
# Column e1461 is missing 95 entries.
# Column e1462 is missing 95 entries.
# Column e1463 is missing 95 entries.
# Column e1464 is missing 95 entries.
# Column e1465 is missing 95 entries.
# Column e1466 is missing 95 entries.
# Column e1467 is missing 95 entries.
# Column e1468 is missing 95 entries.
# Column e1469 is missing 95 entries.
# Column e1470 is missing 95 entries.
# Column e1471 is missing 95 entries.
# Column e1472 is missing 95 entries.
# Column e1473 is missing 95 entries.
# Column e1474 is missing 95 entries.
# Column e1475 is missing 95 entries.
# Column e1476 is missing 95 entries.
# Column e1477 is missing 95 entries.
# Column e1478 is missing 95 entries.
# Column e1479 is missing 95 entries.
# Column e1480 is missing 95 entries.
# Column e1481 is missing 95 entries.
# Column e1482 is missing 95 entries.
# Column e1483 is missing 95 entries.
# Column e1484 is missing 95 entries.
# Column e1485 is missing 95 entries.
# Column e1486 is missing 95 entries.
# Column e1487 is missing 95 entries.
# Column e1488 is missing 95 entries.
# Column e1489 is missing 95 entries.
# Column e1490 is missing 95 entries.
# Column e1491 is missing 95 entries.
# Column e1492 is missing 95 entries.
# Column e1493 is missing 95 entries.
# Column e1494 is missing 95 entries.
# Column e1495 is missing 95 entries.
# Column e1496 is missing 95 entries.
# Column e1497 is missing 95 entries.
# Column e1498 is missing 95 entries.
# Column e1499 is missing 95 entries.
# Column e1500 is missing 95 entries.
# Column e1501 is missing 95 entries.
# Column e1502 is missing 95 entries.
# Column e1503 is missing 95 entries.
# Column e1504 is missing 95 entries.
# Column e1505 is missing 95 entries.
# Column e1506 is missing 95 entries.
# Column e1507 is missing 95 entries.
# Column e1508 is missing 95 entries.
# Column e1509 is missing 95 entries.
# Column e1510 is missing 95 entries.
# Column e1511 is missing 95 entries.
# Column e1512 is missing 95 entries.
# Column e1513 is missing 95 entries.
# Column e1514 is missing 95 entries.
# Column e1515 is missing 95 entries.
# Column e1516 is missing 95 entries.
# Column e1517 is missing 95 entries.
# Column e1518 is missing 95 entries.
# Column e1519 is missing 95 entries.
# Column e1520 is missing 95 entries.
# Column e1521 is missing 95 entries.
# Column e1522 is missing 95 entries.
# Column e1523 is missing 95 entries.
# Column e1524 is missing 95 entries.
# Column e1525 is missing 95 entries.
# Column e1526 is missing 95 entries.
# Column e1527 is missing 95 entries.
# Column e1528 is missing 95 entries.
# Column e1529 is missing 95 entries.
# Column e1530 is missing 95 entries.
# Column e1531 is missing 95 entries.
# Column e1532 is missing 95 entries.
# Column e1533 is missing 95 entries.
# Column e1534 is missing 95 entries.
# Column e1535 is missing 95 entries.
# renewable
# co2
# storage
# services
# materials
# solorrow
# sind
# gmbh
# industry
# do
# page
# project
# solar
# methanol
# companies
# 2021
# projects
# asset
# footprint
# industrial
# change
# its
# scale
# production
# 1

# %%
df
# Out:
#                     Rating    created    changed    expires  \
# Domain
# 1komma5grad.com        2.0 2021-03-31 2022-12-04 2023-03-31
# 2050-materials.com     4.0 2021-02-16 2023-02-17 2025-02-16
# 24ft.de                2.0        NaT        NaT        NaT
# 3dspark.de             2.0        NaT        NaT        NaT
# 42watt.de              4.0        NaT        NaT        NaT
# ...                    ...        ...        ...        ...
# zbs-food.com           2.0 2019-05-08 2019-05-08 2023-05-08
# zeg.ai                 1.0        NaT        NaT        NaT
# zeroavia.com           1.0 2017-10-29 2022-10-22 2023-10-29
# zuluforest.com         3.0 2020-08-17 2022-08-18 2023-08-17
# zunny.life             1.0        NaT        NaT        NaT
#
#                     days_since_created  days_since_changed  \
# Domain
# 1komma5grad.com             815.852575          202.852575
# 2050-materials.com          858.852575          127.852575
# 24ft.de                            NaN                 NaN
# 3dspark.de                         NaN                 NaN
# 42watt.de                          NaN                 NaN
# ...                                ...                 ...
# zbs-food.com               1508.852575         1508.852575
# zeg.ai                             NaN                 NaN
# zeroavia.com               2064.852575          245.852575
# zuluforest.com             1041.852575          310.852575
# zunny.life                         NaN                 NaN
#
#                                                                  text  \
# Domain
# 1komma5grad.com     1KOMMA5° - Klimaneutrale Energiesysteme kaufen...
# 2050-materials.com  2050 Materials - Sustainability Data for Build...
# 24ft.de             Temporäres Wohnen & Arbeiten in Containern | 2...
# 3dspark.de          Home - 3D Spark Home - 3D Spark Toggle navigat...
# 42watt.de           42watt - Energieberatung, Förderservice und Sa...
# ...                                                               ...
# zbs-food.com        Zero Bullshit - Gut für Dich & die Umwelt! Zer...
# zeg.ai              ⭐ ZEG – Your Personal Virtual Studio ⭐ ZEG – Y...
# zeroavia.com        First Practical Zero Emission Aviation Powertr...
# zuluforest.com      Zulu Forest Sciences Zulu Forest Sciences Serv...
# zunny.life
#
#                           e0        e1        e2  ...     e1526     e1527  \
# Domain                                            ...
# 1komma5grad.com          NaN       NaN       NaN  ...       NaN       NaN
# 2050-materials.com  0.005431 -0.002820 -0.016823  ...  0.017510  0.012522
# 24ft.de             0.031842  0.004433  0.027297  ... -0.013292  0.009777
# 3dspark.de         -0.007603 -0.017080 -0.019809  ...  0.010292  0.008045
# 42watt.de           0.017485 -0.004283 -0.004433  ...  0.019542  0.008723
# ...                      ...       ...       ...  ...       ...       ...
# zbs-food.com             NaN       NaN       NaN  ...       NaN       NaN
# zeg.ai             -0.017512 -0.008878 -0.015928  ...  0.013465  0.025604
# zeroavia.com        0.002655 -0.023435 -0.000525  ...  0.005417  0.014120
# zuluforest.com      0.006494 -0.036504 -0.009214  ...  0.020278 -0.002720
# zunny.life               NaN       NaN       NaN  ...       NaN       NaN
#
#                        e1528     e1529     e1530     e1531     e1532  \
# Domain
# 1komma5grad.com          NaN       NaN       NaN       NaN       NaN
# 2050-materials.com  0.039410 -0.007863 -0.029448 -0.040398  0.000554
# 24ft.de             0.066854 -0.021602 -0.006173  0.003640 -0.004737
# 3dspark.de          0.040895 -0.016510 -0.018601 -0.027440  0.008812
# 42watt.de           0.049317 -0.019243 -0.029814  0.001512 -0.000394
# ...                      ...       ...       ...       ...       ...
# zbs-food.com             NaN       NaN       NaN       NaN       NaN
# zeg.ai              0.013370 -0.023358 -0.028933 -0.000631 -0.025469
# zeroavia.com        0.031612 -0.019192 -0.023903 -0.014602  0.001051
# zuluforest.com      0.022006  0.005308 -0.015178 -0.015015 -0.017028
# zunny.life               NaN       NaN       NaN       NaN       NaN
#
#                        e1533     e1534     e1535
# Domain
# 1komma5grad.com          NaN       NaN       NaN
# 2050-materials.com -0.001966 -0.018566 -0.022628
# 24ft.de            -0.005790 -0.016013 -0.037655
# 3dspark.de          0.010034 -0.005859 -0.006290
# 42watt.de           0.002244 -0.021573 -0.026221
# ...                      ...       ...       ...
# zbs-food.com             NaN       NaN       NaN
# zeg.ai              0.009081 -0.005789 -0.048421
# zeroavia.com        0.028052 -0.014254 -0.016061
# zuluforest.com      0.007541 -0.006654 -0.026072
# zunny.life               NaN       NaN       NaN
#
# [734 rows x 1543 columns]

# %%
embeddings = df.filter(regex=r'^e\d+')
ratings = df["Rating"][embeddings.notna().all(axis=1)]
embeddings = embeddings.dropna()

assert ratings.shape[0] == embeddings.shape[0]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = [x.values for x in train_test_split(embeddings, ratings, train_size=0.7, stratify=ratings)]

# %%
from sklearn import linear_model
from sklearn import pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# %%
regressor = linear_model.Ridge()

# %%
regressor.fit(X_train, y_train)
# Out:
# Ridge()

# %%
mean_squared_error(regressor.predict(X_test), y_test), mean_squared_error(regressor.predict(X_train), y_train)
# Out:
# (1.0031744689166764, 0.7212722675015154)

# %%
m = pipeline.Pipeline([("standardscaler", StandardScaler()), ("regressor", regressor)])

# m = pipeline.Pipeline([("regressor", regressor)]) # for ablation

# %%
m.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('regressor', Ridge())])

# %%
mean_squared_error(m.predict(X_test), y_test), mean_squared_error(m.predict(X_train), y_train)
# Out:
# (1.7292273462029726, 0.011947893475815341)

# %%
from sklearn import model_selection

# %%
param_grid = {
    "regressor__alpha": [10**i for i in np.linspace(2, 4, 10)]
}

# %%
cv = model_selection.GridSearchCV(m, param_grid, cv=5, verbose=3, scoring="neg_mean_squared_error")

# %%
cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END ...........regressor__alpha=100.0;, score=-1.390 total time=   0.1s
# [CV 2/5] END ...........regressor__alpha=100.0;, score=-1.314 total time=   0.2s
# [CV 3/5] END ...........regressor__alpha=100.0;, score=-1.325 total time=   0.2s
# [CV 4/5] END ...........regressor__alpha=100.0;, score=-1.443 total time=   0.1s
# [CV 5/5] END ...........regressor__alpha=100.0;, score=-1.293 total time=   0.1s
# [CV 1/5] END regressor__alpha=166.81005372000593;, score=-1.300 total time=   0.2s
# [CV 2/5] END regressor__alpha=166.81005372000593;, score=-1.217 total time=   0.1s
# [CV 3/5] END regressor__alpha=166.81005372000593;, score=-1.247 total time=   0.1s
# [CV 4/5] END regressor__alpha=166.81005372000593;, score=-1.344 total time=   0.1s
# [CV 5/5] END regressor__alpha=166.81005372000593;, score=-1.183 total time=   0.0s
# [CV 1/5] END regressor__alpha=278.2559402207126;, score=-1.210 total time=   0.0s
# [CV 2/5] END regressor__alpha=278.2559402207126;, score=-1.120 total time=   0.0s
# [CV 3/5] END regressor__alpha=278.2559402207126;, score=-1.174 total time=   0.0s
# [CV 4/5] END regressor__alpha=278.2559402207126;, score=-1.246 total time=   0.0s
# [CV 5/5] END regressor__alpha=278.2559402207126;, score=-1.080 total time=   0.0s
# [CV 1/5] END regressor__alpha=464.15888336127773;, score=-1.130 total time=   0.1s
# [CV 2/5] END regressor__alpha=464.15888336127773;, score=-1.037 total time=   0.1s
# [CV 3/5] END regressor__alpha=464.15888336127773;, score=-1.116 total time=   0.1s
# [CV 4/5] END regressor__alpha=464.15888336127773;, score=-1.156 total time=   0.1s
# [CV 5/5] END regressor__alpha=464.15888336127773;, score=-0.992 total time=   0.1s
# [CV 1/5] END regressor__alpha=774.263682681127;, score=-1.064 total time=   0.1s
# [CV 2/5] END regressor__alpha=774.263682681127;, score=-0.974 total time=   0.1s
# [CV 3/5] END regressor__alpha=774.263682681127;, score=-1.076 total time=   0.1s
# [CV 4/5] END regressor__alpha=774.263682681127;, score=-1.082 total time=   0.1s
# [CV 5/5] END regressor__alpha=774.263682681127;, score=-0.928 total time=   0.1s
# [CV 1/5] END regressor__alpha=1291.549665014884;, score=-1.016 total time=   0.1s
# [CV 2/5] END regressor__alpha=1291.549665014884;, score=-0.936 total time=   0.0s
# [CV 3/5] END regressor__alpha=1291.549665014884;, score=-1.058 total time=   0.1s
# [CV 4/5] END regressor__alpha=1291.549665014884;, score=-1.025 total time=   0.1s
# [CV 5/5] END regressor__alpha=1291.549665014884;, score=-0.888 total time=   0.1s
# [CV 1/5] END regressor__alpha=2154.4346900318824;, score=-0.988 total time=   0.1s
# [CV 2/5] END regressor__alpha=2154.4346900318824;, score=-0.923 total time=   0.1s
# [CV 3/5] END regressor__alpha=2154.4346900318824;, score=-1.062 total time=   0.1s
# [CV 4/5] END regressor__alpha=2154.4346900318824;, score=-0.990 total time=   0.1s
# [CV 5/5] END regressor__alpha=2154.4346900318824;, score=-0.871 total time=   0.1s
# [CV 1/5] END regressor__alpha=3593.813663804626;, score=-0.981 total time=   0.1s
# [CV 2/5] END regressor__alpha=3593.813663804626;, score=-0.933 total time=   0.1s
# [CV 3/5] END regressor__alpha=3593.813663804626;, score=-1.085 total time=   0.1s
# [CV 4/5] END regressor__alpha=3593.813663804626;, score=-0.980 total time=   0.1s
# [CV 5/5] END regressor__alpha=3593.813663804626;, score=-0.875 total time=   0.1s
# [CV 1/5] END regressor__alpha=5994.8425031894085;, score=-0.993 total time=   0.2s
# [CV 2/5] END regressor__alpha=5994.8425031894085;, score=-0.965 total time=   0.2s
# [CV 3/5] END regressor__alpha=5994.8425031894085;, score=-1.124 total time=   0.1s
# [CV 4/5] END regressor__alpha=5994.8425031894085;, score=-0.997 total time=   0.1s
# [CV 5/5] END regressor__alpha=5994.8425031894085;, score=-0.900 total time=   0.1s
# [CV 1/5] END .........regressor__alpha=10000.0;, score=-1.024 total time=   0.1s
# [CV 2/5] END .........regressor__alpha=10000.0;, score=-1.017 total time=   0.1s
# [CV 3/5] END .........regressor__alpha=10000.0;, score=-1.176 total time=   0.1s
# [CV 4/5] END .........regressor__alpha=10000.0;, score=-1.045 total time=   0.1s
# [CV 5/5] END .........regressor__alpha=10000.0;, score=-0.947 total time=   0.1s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('regressor', Ridge())]),
#              param_grid={'regressor__alpha': [100.0, 166.81005372000593,
#                                               278.2559402207126,
#                                               464.15888336127773,
#                                               774.263682681127,
#                                               1291.549665014884,
#                                               2154.4346900318824,
#                                               3593.813663804626,
#                                               5994.8425031894085, 10000.0]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
list(zip(cv.cv_results_["params"], cv.cv_results_["mean_test_score"]))
# Out:
# [({'regressor__alpha': 100.0}, -1.3529300163498907),
#  ({'regressor__alpha': 166.81005372000593}, -1.2581189513410374),
#  ({'regressor__alpha': 278.2559402207126}, -1.1660504786113344),
#  ({'regressor__alpha': 464.15888336127773}, -1.086129003089098),
#  ({'regressor__alpha': 774.263682681127}, -1.0247176769359208),
#  ({'regressor__alpha': 1291.549665014884}, -0.9847423673605735),
#  ({'regressor__alpha': 2154.4346900318824}, -0.9668213315038189),
#  ({'regressor__alpha': 3593.813663804626}, -0.9706512308093014),
#  ({'regressor__alpha': 5994.8425031894085}, -0.9957688035095824),
#  ({'regressor__alpha': 10000.0}, -1.041642100832177)]

# %%
predictions_train = cv.best_estimator_.predict(X_train)
predictions_test = cv.best_estimator_.predict(X_test)

# %%
mean_squared_error(predictions_train, y_train), mean_squared_error(predictions_test, y_test)
# Out:
# (0.49814566481536604, 0.9934220455234609)
